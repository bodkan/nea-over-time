# %% [markdown]
# # Simulating Neanderthal ancestry trajectories on exons only

# %% [markdown]
# The goal here is to investigate the behavior of Neanderthal ancestry over time in models of selection against Neanderthal ancestry in exome that include linkage/recombination.

# %%
import glob

import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 6)

# %%
def read_trajectories(path_pattern):
    """Read Nea. trajectories from a given set of output files."""
    return pd.concat(pd.read_table(f, index_col=False, sep='\t')
                     for f in glob.glob(path_pattern))
    

def plot_trajectories(ancestry, *, ylim=0.15, avg=False, admixture_time=55000):
    fig, ax = plt.subplots(1, 2)

    ax[0].plot(ancestry.mean() if avg else ancestry.T)
    ax[0].set_xlim(1, int(admixture_time/25))
    ax[0].set_ylim(0, ylim)
    ax[0].set_ylabel('Proportion of the Neanderthal ancestry')
    ax[0].set_xlabel('Generation since the admixture')

    ax[1].plot(ancestry.mean() if avg else ancestry.T)
    ax[1].set_xlim(1, int(admixture_time/25))
    ax[1].set_ylim(0, ylim)
    ax[1].set_xscale('log')
    ax[1].set_ylabel('Proportion of the Neanderthal ancestry')
    ax[1].set_xlabel('LOG generation since the admixture')

# %% [markdown]
# # Spacing $10^4$ bp

# %% [markdown]
# # h = 0.5

# %%
trajectories = read_trajectories('../tests/output__h_0.5__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # h = 0.1

# %%
trajectories = read_trajectories('../tests/output__h_0.1__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # h = 0.0

# %%
trajectories = read_trajectories('../tests/output__h_0.0__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # Harris and Nielsen recombination map
#
# # h = 0.5

# %%
trajectories = read_trajectories('../tests/harris__output__h_0.5__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # h = 0.1

# %%
trajectories = read_trajectories('../tests/harris__output__h_0.1__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # h = 0.0

# %%
trajectories = read_trajectories('../tests/harris__output__h_0.0__*')

# %%
plot_trajectories(trajectories)

# %%
plot_trajectories(trajectories, avg=True)

# %% [markdown]
# # h = 0.0, lower admixture rate

# %%
trajectories = read_trajectories('../tests/harris__output__lower_admixture__h_0.0__*')

# %%
plot_trajectories(trajectories, ylim=0.05)

# %%
plot_trajectories(trajectories, ylim=0.05, avg=True)
